# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("main.csv",index_col=32)

# %%
print(df.describe().T)
# Out:
#                          count          mean           std          min  \
# id                       569.0  3.037183e+07  1.250206e+08  8670.000000
# radius_mean              569.0  1.412729e+01  3.524049e+00     6.981000
# texture_mean             569.0  1.928965e+01  4.301036e+00     9.710000
# perimeter_mean           569.0  9.196903e+01  2.429898e+01    43.790000
# area_mean                569.0  6.548891e+02  3.519141e+02   143.500000
# smoothness_mean          569.0  9.636028e-02  1.406413e-02     0.052630
# compactness_mean         569.0  1.043410e-01  5.281276e-02     0.019380
# concavity_mean           569.0  8.879932e-02  7.971981e-02     0.000000
# concave points_mean      569.0  4.891915e-02  3.880284e-02     0.000000
# symmetry_mean            569.0  1.811619e-01  2.741428e-02     0.106000
# fractal_dimension_mean   569.0  6.279761e-02  7.060363e-03     0.049960
# radius_se                569.0  4.051721e-01  2.773127e-01     0.111500
# texture_se               569.0  1.216853e+00  5.516484e-01     0.360200
# perimeter_se             569.0  2.866059e+00  2.021855e+00     0.757000
# area_se                  569.0  4.033708e+01  4.549101e+01     6.802000
# smoothness_se            569.0  7.040979e-03  3.002518e-03     0.001713
# compactness_se           569.0  2.547814e-02  1.790818e-02     0.002252
# concavity_se             569.0  3.189372e-02  3.018606e-02     0.000000
# concave points_se        569.0  1.179614e-02  6.170285e-03     0.000000
# symmetry_se              569.0  2.054230e-02  8.266372e-03     0.007882
# fractal_dimension_se     569.0  3.794904e-03  2.646071e-03     0.000895
# radius_worst             569.0  1.626919e+01  4.833242e+00     7.930000
# texture_worst            569.0  2.567722e+01  6.146258e+00    12.020000
# perimeter_worst          569.0  1.072612e+02  3.360254e+01    50.410000
# area_worst               569.0  8.805831e+02  5.693570e+02   185.200000
# smoothness_worst         569.0  1.323686e-01  2.283243e-02     0.071170
# compactness_worst        569.0  2.542650e-01  1.573365e-01     0.027290
# concavity_worst          569.0  2.721885e-01  2.086243e-01     0.000000
# concave points_worst     569.0  1.146062e-01  6.573234e-02     0.000000
# symmetry_worst           569.0  2.900756e-01  6.186747e-02     0.156500
# fractal_dimension_worst  569.0  8.394582e-02  1.806127e-02     0.055040
#
#                                    25%            50%           75%  \
# id                       869218.000000  906024.000000  8.813129e+06
# radius_mean                  11.700000      13.370000  1.578000e+01
# texture_mean                 16.170000      18.840000  2.180000e+01
# perimeter_mean               75.170000      86.240000  1.041000e+02
# area_mean                   420.300000     551.100000  7.827000e+02
# smoothness_mean               0.086370       0.095870  1.053000e-01
# compactness_mean              0.064920       0.092630  1.304000e-01
# concavity_mean                0.029560       0.061540  1.307000e-01
# concave points_mean           0.020310       0.033500  7.400000e-02
# symmetry_mean                 0.161900       0.179200  1.957000e-01
# fractal_dimension_mean        0.057700       0.061540  6.612000e-02
# radius_se                     0.232400       0.324200  4.789000e-01
# texture_se                    0.833900       1.108000  1.474000e+00
# perimeter_se                  1.606000       2.287000  3.357000e+00
# area_se                      17.850000      24.530000  4.519000e+01
# smoothness_se                 0.005169       0.006380  8.146000e-03
# compactness_se                0.013080       0.020450  3.245000e-02
# concavity_se                  0.015090       0.025890  4.205000e-02
# concave points_se             0.007638       0.010930  1.471000e-02
# symmetry_se                   0.015160       0.018730  2.348000e-02
# fractal_dimension_se          0.002248       0.003187  4.558000e-03
# radius_worst                 13.010000      14.970000  1.879000e+01
# texture_worst                21.080000      25.410000  2.972000e+01
# perimeter_worst              84.110000      97.660000  1.254000e+02
# area_worst                  515.300000     686.500000  1.084000e+03
# smoothness_worst              0.116600       0.131300  1.460000e-01
# compactness_worst             0.147200       0.211900  3.391000e-01
# concavity_worst               0.114500       0.226700  3.829000e-01
# concave points_worst          0.064930       0.099930  1.614000e-01
# symmetry_worst                0.250400       0.282200  3.179000e-01
# fractal_dimension_worst       0.071460       0.080040  9.208000e-02
#
#                                   max
# id                       9.113205e+08
# radius_mean              2.811000e+01
# texture_mean             3.928000e+01
# perimeter_mean           1.885000e+02
# area_mean                2.501000e+03
# smoothness_mean          1.634000e-01
# compactness_mean         3.454000e-01
# concavity_mean           4.268000e-01
# concave points_mean      2.012000e-01
# symmetry_mean            3.040000e-01
# fractal_dimension_mean   9.744000e-02
# radius_se                2.873000e+00
# texture_se               4.885000e+00
# perimeter_se             2.198000e+01
# area_se                  5.422000e+02
# smoothness_se            3.113000e-02
# compactness_se           1.354000e-01
# concavity_se             3.960000e-01
# concave points_se        5.279000e-02
# symmetry_se              7.895000e-02
# fractal_dimension_se     2.984000e-02
# radius_worst             3.604000e+01
# texture_worst            4.954000e+01
# perimeter_worst          2.512000e+02
# area_worst               4.254000e+03
# smoothness_worst         2.226000e-01
# compactness_worst        1.058000e+00
# concavity_worst          1.252000e+00
# concave points_worst     2.910000e-01
# symmetry_worst           6.638000e-01
# fractal_dimension_worst  2.075000e-01

# %%
print(df.isnull().sum())
#df = df.dropna()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
# Rename 'Diagnosis' column to 'Label'
df['Label'] = df['diagnosis']
df = df.drop(columns=['diagnosis'])

# Print data types of columns
print(df.dtypes)
# Out:
# id                           int64
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# Label                       object
# dtype: object

# %%
#Understand the data
sns.countplot(x="Label", data=df) #M - malignant   B - benign
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
####### Replace categorical values with numbers########
print("Distribution of data: ", df['Label'].value_counts())

#Define the dependent variable that needs to be predicted (labels)
y = df["Label"].values
print("Labels before encoding are: ", np.unique(y))

# Encoding categorical data from text (B and M) to integers (0 and 1)
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
Y = labelencoder.fit_transform(y) # M=1 and B=0
print("Labels after encoding are: ", np.unique(Y))
# Out:
# Distribution of data:  Label
# B    357
# M    212
# Name: count, dtype: int64
# Labels before encoding are:  ['B' 'M']
# Labels after encoding are:  [0 1]

# %%
#Define x and normalize / scale values

#Define the independent variables. Drop label and ID, and normalize other data
X = df.drop(labels = ["Label", "id"], axis=1)
print(X.describe().T) #Needs scaling
# Out:
#                          count        mean         std         min  \
# radius_mean              569.0   14.127292    3.524049    6.981000
# texture_mean             569.0   19.289649    4.301036    9.710000
# perimeter_mean           569.0   91.969033   24.298981   43.790000
# area_mean                569.0  654.889104  351.914129  143.500000
# smoothness_mean          569.0    0.096360    0.014064    0.052630
# compactness_mean         569.0    0.104341    0.052813    0.019380
# concavity_mean           569.0    0.088799    0.079720    0.000000
# concave points_mean      569.0    0.048919    0.038803    0.000000
# symmetry_mean            569.0    0.181162    0.027414    0.106000
# fractal_dimension_mean   569.0    0.062798    0.007060    0.049960
# radius_se                569.0    0.405172    0.277313    0.111500
# texture_se               569.0    1.216853    0.551648    0.360200
# perimeter_se             569.0    2.866059    2.021855    0.757000
# area_se                  569.0   40.337079   45.491006    6.802000
# smoothness_se            569.0    0.007041    0.003003    0.001713
# compactness_se           569.0    0.025478    0.017908    0.002252
# concavity_se             569.0    0.031894    0.030186    0.000000
# concave points_se        569.0    0.011796    0.006170    0.000000
# symmetry_se              569.0    0.020542    0.008266    0.007882
# fractal_dimension_se     569.0    0.003795    0.002646    0.000895
# radius_worst             569.0   16.269190    4.833242    7.930000
# texture_worst            569.0   25.677223    6.146258   12.020000
# perimeter_worst          569.0  107.261213   33.602542   50.410000
# area_worst               569.0  880.583128  569.356993  185.200000
# smoothness_worst         569.0    0.132369    0.022832    0.071170
# compactness_worst        569.0    0.254265    0.157336    0.027290
# concavity_worst          569.0    0.272188    0.208624    0.000000
# concave points_worst     569.0    0.114606    0.065732    0.000000
# symmetry_worst           569.0    0.290076    0.061867    0.156500
# fractal_dimension_worst  569.0    0.083946    0.018061    0.055040
#
#                                 25%         50%          75%         max
# radius_mean               11.700000   13.370000    15.780000    28.11000
# texture_mean              16.170000   18.840000    21.800000    39.28000
# perimeter_mean            75.170000   86.240000   104.100000   188.50000
# area_mean                420.300000  551.100000   782.700000  2501.00000
# smoothness_mean            0.086370    0.095870     0.105300     0.16340
# compactness_mean           0.064920    0.092630     0.130400     0.34540
# concavity_mean             0.029560    0.061540     0.130700     0.42680
# concave points_mean        0.020310    0.033500     0.074000     0.20120
# symmetry_mean              0.161900    0.179200     0.195700     0.30400
# fractal_dimension_mean     0.057700    0.061540     0.066120     0.09744
# radius_se                  0.232400    0.324200     0.478900     2.87300
# texture_se                 0.833900    1.108000     1.474000     4.88500
# perimeter_se               1.606000    2.287000     3.357000    21.98000
# area_se                   17.850000   24.530000    45.190000   542.20000
# smoothness_se              0.005169    0.006380     0.008146     0.03113
# compactness_se             0.013080    0.020450     0.032450     0.13540
# concavity_se               0.015090    0.025890     0.042050     0.39600
# concave points_se          0.007638    0.010930     0.014710     0.05279
# symmetry_se                0.015160    0.018730     0.023480     0.07895
# fractal_dimension_se       0.002248    0.003187     0.004558     0.02984
# radius_worst              13.010000   14.970000    18.790000    36.04000
# texture_worst             21.080000   25.410000    29.720000    49.54000
# perimeter_worst           84.110000   97.660000   125.400000   251.20000
# area_worst               515.300000  686.500000  1084.000000  4254.00000
# smoothness_worst           0.116600    0.131300     0.146000     0.22260
# compactness_worst          0.147200    0.211900     0.339100     1.05800
# concavity_worst            0.114500    0.226700     0.382900     1.25200
# concave points_worst       0.064930    0.099930     0.161400     0.29100
# symmetry_worst             0.250400    0.282200     0.317900     0.66380
# fractal_dimension_worst    0.071460    0.080040     0.092080     0.20750

# %%
#Scale / normalize the values to bring them to similar range
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X)
X = scaler.transform(X)
print(X)  #Scaled values
# Out:
# [[0.52103744 0.0226581  0.54598853 ... 0.91202749 0.59846245 0.41886396]
#  [0.64314449 0.27257355 0.61578329 ... 0.63917526 0.23358959 0.22287813]
#  [0.60149557 0.3902604  0.59574321 ... 0.83505155 0.40370589 0.21343303]
#  ...
#  [0.45525108 0.62123774 0.44578813 ... 0.48728522 0.12872068 0.1519087 ]
#  [0.64456434 0.66351031 0.66553797 ... 0.91065292 0.49714173 0.45231536]
#  [0.03686876 0.50152181 0.02853984 ... 0.         0.25744136 0.10068215]]

# %% [markdown]
# **using PCA**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)
x_pca = pca.fit_transform(X)
x_pca.shape
# Out:
# (569, 10)

# %%
#Split data into train and test to verify accuracy after fitting the model.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_pca, Y, test_size=0.25, random_state=42)
print("Shape of training data is: ", X_train.shape)
print("Shape of testing data is: ", X_test.shape)
# Out:
# Shape of training data is:  (426, 10)
# Shape of testing data is:  (143, 10)

# %% [markdown]
# **Machine learning models**

# %%
def models(X_train,y_train):

  #Using Logistic Regression Algorithm to the Training Set
    from sklearn.linear_model import LogisticRegression
    log=LogisticRegression(random_state = 0)
    log.fit(X_train, y_train)

  #Using KNeighborsClassifier Method of neighbors class to use Nearest Neighbor algorithm
    from sklearn.neighbors import KNeighborsClassifier
    knn=KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    knn.fit(X_train, y_train)

  #Using DecisionTreeClassifier of tree class to use Decision Tree Algorithm
    from sklearn.tree import DecisionTreeClassifier
    tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
    tree.fit(X_train, y_train)

 #Using GaussianNB method of naïve_bayes class to use Naïve Bayes Algorithm
    from sklearn.naive_bayes import GaussianNB
    gauss = GaussianNB()
    gauss.fit(X_train, y_train)

#Using RandomForestClassifier method of ensemble class to use Random Forest Classification algorithm
    from sklearn.ensemble import RandomForestClassifier
    forest = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
    forest.fit(X_train, y_train)
#Using SVC method of svm class to use Support Vector Machine Algorithm
    from sklearn.svm import SVC
    svc_lin = SVC(kernel = 'linear', random_state = 0)
    svc_lin.fit(X_train, y_train)


  #print model accuracy on the training data.
    print('[0]Logistic Regression Training Accuracy:', log.score(X_train, y_train))
    print('[1]K Nearest Neighbor Training Accuracy:', knn.score(X_train, y_train))
    print('[2]Decision Tree Classifier Training Accuracy:', tree.score(X_train, y_train))
    print('[3]Gaussian Naive Bayes Training Accuracy:', gauss.score(X_train, y_train))
    print('[4]Random Forest Classifier Training Accuracy:', forest.score(X_train, y_train))
    print('[5]Support Vector Machine (Linear Classifier) Training Accuracy:', svc_lin.score(X_train, y_train))


    return log, knn,tree,gauss, forest,svc_lin
mdl = models(X_train,y_train)
# import warnings filter
from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)
# Out:
# [0]Logistic Regression Training Accuracy: 0.9671361502347418
# [1]K Nearest Neighbor Training Accuracy: 0.9812206572769953
# [2]Decision Tree Classifier Training Accuracy: 1.0
# [3]Gaussian Naive Bayes Training Accuracy: 0.9295774647887324
# [4]Random Forest Classifier Training Accuracy: 0.9976525821596244
# [5]Support Vector Machine (Linear Classifier) Training Accuracy: 0.9741784037558685

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Loop through each model
for i, mdl in enumerate(mdl):
    # Calculate the confusion matrix
    cm = confusion_matrix(y_test, mdl.predict(X_test))

    TN = cm[0][0]
    TP = cm[1][1]
    FN = cm[1][0]
    FP = cm[0][1]

    print(cm)
    print('Model[{}] Testing Accuracy = "{}!"'.format(i, (TP + TN) / (TP + TN + FN + FP)))
    print()  # Print a new line

    # Plot the heatmap
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'Model {i} Confusion Matrix')
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()
# Out:
# [[89  0]
#  [ 2 52]]
# Model[0] Testing Accuracy = "0.986013986013986!"
# [[87  2]
#  [ 3 51]]
# Model[1] Testing Accuracy = "0.965034965034965!"
# [[85  4]
#  [ 2 52]]
# Model[2] Testing Accuracy = "0.958041958041958!"
# [[84  5]
#  [ 5 49]]
# Model[3] Testing Accuracy = "0.9300699300699301!"
# [[83  6]
#  [ 3 51]]
# Model[4] Testing Accuracy = "0.9370629370629371!"
# [[89  0]
#  [ 2 52]]
# Model[5] Testing Accuracy = "0.986013986013986!"

# %% [markdown]
# **using neural networks**

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout

# %%
model = Sequential()
model.add(Dense(14, input_dim=10, activation='relu'))
model.add(Dropout(0.35))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 14)                154
#
#  dropout_2 (Dropout)         (None, 14)                0
#
#  dense_5 (Dense)             (None, 1)                 15
#
#  activation_2 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 169 (676.00 Byte)
# Trainable params: 169 (676.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
#Fit with no early stopping or other callbacks
history = model.fit(X_train, y_train, verbose=1, epochs=100, batch_size=40,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0562 - accuracy: 0.9883 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 2/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9883 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 3/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0681 - accuracy: 0.9742 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 4/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0763 - accuracy: 0.9671 - val_loss: 0.0489 - val_accuracy: 0.9930
# Epoch 5/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0656 - accuracy: 0.9836 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 6/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0696 - accuracy: 0.9718 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 7/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9789 - val_loss: 0.0494 - val_accuracy: 0.9930
# Epoch 8/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 0.9812 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 9/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0769 - accuracy: 0.9718 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 10/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0700 - accuracy: 0.9789 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 11/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0571 - accuracy: 0.9836 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 12/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0616 - accuracy: 0.9836 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 13/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.9765 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 14/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0604 - accuracy: 0.9812 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 15/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0732 - accuracy: 0.9765 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 16/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0654 - accuracy: 0.9765 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 17/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0600 - accuracy: 0.9789 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 18/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0626 - accuracy: 0.9765 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 19/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0783 - accuracy: 0.9742 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 20/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0682 - accuracy: 0.9859 - val_loss: 0.0496 - val_accuracy: 0.9930
# Epoch 21/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0743 - accuracy: 0.9765 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 22/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0700 - accuracy: 0.9742 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 23/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0724 - accuracy: 0.9695 - val_loss: 0.0496 - val_accuracy: 0.9930
# Epoch 24/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0731 - accuracy: 0.9742 - val_loss: 0.0498 - val_accuracy: 0.9930
# Epoch 25/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0781 - accuracy: 0.9695 - val_loss: 0.0500 - val_accuracy: 0.9930
# Epoch 26/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0748 - accuracy: 0.9742 - val_loss: 0.0502 - val_accuracy: 0.9860
# Epoch 27/100
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9812 - val_loss: 0.0502 - val_accuracy: 0.9860
# Epoch 28/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0667 - accuracy: 0.9695 - val_loss: 0.0499 - val_accuracy: 0.9860
# Epoch 29/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0741 - accuracy: 0.9718 - val_loss: 0.0494 - val_accuracy: 0.9930
# Epoch 30/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9765 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 31/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0768 - accuracy: 0.9695 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 32/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0731 - accuracy: 0.9765 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 33/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0654 - accuracy: 0.9812 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 34/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0628 - accuracy: 0.9695 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 35/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0615 - accuracy: 0.9812 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 36/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0614 - accuracy: 0.9812 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 37/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0632 - accuracy: 0.9812 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 38/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0680 - accuracy: 0.9789 - val_loss: 0.0482 - val_accuracy: 0.9930
# Epoch 39/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0651 - accuracy: 0.9742 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 40/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0632 - accuracy: 0.9812 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 41/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0671 - accuracy: 0.9789 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 42/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0655 - accuracy: 0.9765 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 43/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0658 - accuracy: 0.9789 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 44/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0676 - accuracy: 0.9836 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 45/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0528 - accuracy: 0.9812 - val_loss: 0.0489 - val_accuracy: 0.9930
# Epoch 46/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0584 - accuracy: 0.9812 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 47/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0752 - accuracy: 0.9742 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 48/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0610 - accuracy: 0.9765 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 49/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0498 - accuracy: 0.9836 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 50/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0665 - accuracy: 0.9789 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 51/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0794 - accuracy: 0.9765 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 52/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0542 - accuracy: 0.9883 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 53/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0592 - accuracy: 0.9812 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 54/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0657 - accuracy: 0.9906 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 55/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9695 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 56/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0694 - accuracy: 0.9765 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 57/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0628 - accuracy: 0.9742 - val_loss: 0.0485 - val_accuracy: 0.9930
# Epoch 58/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0654 - accuracy: 0.9742 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 59/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0655 - accuracy: 0.9812 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 60/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0796 - accuracy: 0.9742 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 61/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0620 - accuracy: 0.9812 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 62/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0586 - accuracy: 0.9742 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 63/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0583 - accuracy: 0.9742 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 64/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0643 - accuracy: 0.9836 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 65/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0668 - accuracy: 0.9812 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 66/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0617 - accuracy: 0.9789 - val_loss: 0.0482 - val_accuracy: 0.9930
# Epoch 67/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0750 - accuracy: 0.9718 - val_loss: 0.0482 - val_accuracy: 0.9930
# Epoch 68/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0780 - accuracy: 0.9695 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 69/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0607 - accuracy: 0.9789 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 70/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0646 - accuracy: 0.9789 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 71/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0559 - accuracy: 0.9859 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 72/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0627 - accuracy: 0.9812 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 73/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0806 - accuracy: 0.9765 - val_loss: 0.0484 - val_accuracy: 0.9930
# Epoch 74/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0640 - accuracy: 0.9765 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 75/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0690 - accuracy: 0.9695 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 76/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0588 - accuracy: 0.9836 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 77/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0610 - accuracy: 0.9859 - val_loss: 0.0487 - val_accuracy: 0.9930
# Epoch 78/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0633 - accuracy: 0.9812 - val_loss: 0.0486 - val_accuracy: 0.9930
# Epoch 79/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 0.9812 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 80/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9836 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 81/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0591 - accuracy: 0.9836 - val_loss: 0.0488 - val_accuracy: 0.9930
# Epoch 82/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 0.9812 - val_loss: 0.0489 - val_accuracy: 0.9930
# Epoch 83/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0714 - accuracy: 0.9789 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 84/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0537 - accuracy: 0.9836 - val_loss: 0.0492 - val_accuracy: 0.9860
# Epoch 85/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0612 - accuracy: 0.9789 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 86/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0585 - accuracy: 0.9789 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 87/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0606 - accuracy: 0.9789 - val_loss: 0.0491 - val_accuracy: 0.9930
# Epoch 88/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0644 - accuracy: 0.9765 - val_loss: 0.0489 - val_accuracy: 0.9930
# Epoch 89/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0595 - accuracy: 0.9765 - val_loss: 0.0489 - val_accuracy: 0.9930
# Epoch 90/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0675 - accuracy: 0.9836 - val_loss: 0.0490 - val_accuracy: 0.9930
# Epoch 91/100
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0625 - accuracy: 0.9789 - val_loss: 0.0492 - val_accuracy: 0.9930
# Epoch 92/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0497 - accuracy: 0.9812 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 93/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0665 - accuracy: 0.9836 - val_loss: 0.0496 - val_accuracy: 0.9930
# Epoch 94/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0768 - accuracy: 0.9695 - val_loss: 0.0495 - val_accuracy: 0.9930
# Epoch 95/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0635 - accuracy: 0.9789 - val_loss: 0.0496 - val_accuracy: 0.9930
# Epoch 96/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0691 - accuracy: 0.9789 - val_loss: 0.0501 - val_accuracy: 0.9860
# Epoch 97/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9765 - val_loss: 0.0500 - val_accuracy: 0.9860
# Epoch 98/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0771 - accuracy: 0.9765 - val_loss: 0.0501 - val_accuracy: 0.9860
# Epoch 99/100
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0694 - accuracy: 0.9812 - val_loss: 0.0504 - val_accuracy: 0.9860
# Epoch 100/100
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0682 - accuracy: 0.9718 - val_loss: 0.0504 - val_accuracy: 0.9860

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['accuracy']  #Use accuracy if acc doesn't work
val_acc = history.history['val_accuracy']  #Use val_accuracy if acc doesn't work
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Predicting the Test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)
# Out:
# 5/5 [==============================] - 0s 9ms/step
# <Axes: >

# %%
import matplotlib.pyplot as plt

# Training accuracies
train_accuracies = [0.9671361502347418, 0.9812206572769953, 1.0, 0.9366197183098591, 0.9976525821596244, 0.9788732394366197,0.9836 ]

# Testing accuracies
test_accuracies = [0.9790209790209791,0.958041958041958,0.958041958041958,0.951048951048951, 0.972027972027972,0.972027972027972,0.9930]  # Fill this list with your actual testing accuracies

# Model names
model_names = [
    'Logistic Regression',
    'K Nearest Neighbor',
    'Decision Tree Classifier',
    'Gaussian Naive Bayes',
    'Random Forest Classifier',
    'Support Vector Machine (Linear Classifier)',
    'proposed method ( Multilayer perciption)'
]

# Plotting
plt.figure(figsize=(14, 6))

# Plot training accuracy
bars_train = plt.bar([i - 0.2 for i in range(len(train_accuracies))], train_accuracies, width=0.4, color='blue', label='Training Accuracy')

# Plot testing accuracy
bars_test = plt.bar([i + 0.2 for i in range(len(test_accuracies))], test_accuracies, width=0.4, color='green', label='Testing Accuracy')

# Adding labels and title
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.title('Training and Testing Accuracy of Models')
plt.xticks(range(len(model_names)), model_names, rotation=45, ha='right')

# Adding accuracy rate on top of each bar
for bars, accuracies in zip([bars_train, bars_test], [train_accuracies, test_accuracies]):
    for bar, acc in zip(bars, accuracies):
        plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.01, '{:.2f}%'.format(acc * 100),
                 ha='center', va='bottom')

# Adding legend
plt.legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
